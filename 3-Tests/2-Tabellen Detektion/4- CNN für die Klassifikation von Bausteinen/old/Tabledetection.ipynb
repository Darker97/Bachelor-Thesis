# %%
# !pip install faker
# !pip install tqdm
# Out:
# Collecting faker
#   Downloading https://files.pythonhosted.org/packages/de/21/a0c2ed68ca140d0a5bd0ac762f05cbe03dd52ffb577ae5d5c973dc85e103/Faker-4.1.1-py3-none-any.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 4.6MB/s
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.6/dist-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4->faker) (1.12.0)
# Installing collected packages: faker
# Successfully installed faker-4.1.1
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %%
import sys
import requests
import tarfile
import json
import numpy as np
from os import path
from PIL import Image
from PIL import ImageFont, ImageDraw
from glob import glob
from matplotlib import pyplot as plt

import random
from tqdm import tqdm

from faker import Faker
import re
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import CSVLogger

# %% [markdown]
# # Laden der Daten

# %%
def Download(fname):
  url = 'https://dax-cdn.cdn.appdomain.cloud/dax-publaynet/1.0.0/' + fname

  r = requests.get(url)
  open(fname , 'wb').write(r.content)
  print("Geladen")
  # Extracting the dataset
  tar = tarfile.open(fname)
  tar.extractall()
  tar.close()

# %%
#fname = 'examples.tar.gz'
#Download(fname)
# Out:
# Geladen

# %%
fname = 'labels.tar.gz'
Download(fname)
# Out:
# Geladen

# %%
fname = 'train-0.tar.gz'
Download(fname)

# %%
fname = 'train-1.tar.gz'
Download(fname)

# %%
# Parse the JSON file and read all the images and labels
with open('publaynet/train.json', 'r') as fp:
    samples = json.load(fp)
# Index images
images = {}
for image in samples['images']:
    images[image['id']] = {'file_name': "publaynet/train/" + image['file_name'], 'annotations': []}
for ann in samples['annotations']:
    images[ann['image_id']]['annotations'].append(ann)

# %%
# Function to viz the annotation
def markup(image, annotations):
    ''' Draws the segmentation, bounding box, and label of each annotation
    '''
    draw = ImageDraw.Draw(image, 'RGBA')
    for annotation in annotations:
        # Draw bbox
        # "bbox": [37.59, 433.64, 251.07, 20.38]
      tempImage = image.crop((annotation['bbox'][0],
            annotation['bbox'][1],
            annotation['bbox'][0] + annotation['bbox'][2],
            annotation['bbox'][1] + annotation['bbox'][3]))
      tempImage = tempImage.resize((120,120))
      Kategorie = outline=samples['categories'][annotation['category_id'] - 1]['id']
    return np.array(tempImage), np.array(Kategorie)

# %%
def createZielDaten(Number):
  Ziel = []
  for i in range(0,6):
    Ziel.append(0)
  Ziel[Number] = 1
  return Ziel

# %% [markdown]
# # Vorbereitung fürs Netz

# %%
# text ("1"), title ("2"), list ("3"), table ("4"), figure ("5").
# "bbox": [37.59, 360.34, 251.07, 41.36]

x = []
y = []

# Ausschneiden und ausgeben
for i, (_, image) in enumerate(images.items()):
  try:
    with Image.open(image['file_name']) as img:
      TempImage, Kategorie = markup(img, image['annotations'])
      x.append(TempImage)
      y.append(Kategorie)
  except Exception:
    continue

temp_Zieldaten = y
y = []

for i in temp_Zieldaten:
  y.append(createZielDaten(i))

x = np.array(x)
y = np.array(y)

print(x.shape)
print(y.shape)
# Out:
# (20, 120, 120, 3)
# (20, 6)

# %% [markdown]
# # Bau des Models

# %%
x = np.array(x)
y = np.array(y)

# %% [markdown]
# Wir haben 5 verschiedene Kategorien:
#
# 1.   title
# 2.   text
# 3.   figure
# 4.   tabel
# 5.   list

# %%
input = keras.layers.Input((120,120,3))

CNN = keras.layers.Conv2D(60, (2,2) , activation='relu')(input)
CNN = keras.layers.MaxPooling2D((2,2))(input)
CNN = keras.layers.Conv2D(64, (3,3), activation='relu')(CNN)
CNN = keras.layers.MaxPooling2D((2,2))(CNN)
CNN = keras.layers.Conv2D(32, (3,3), activation='relu')(CNN)

Wertung = keras.layers.Flatten()(CNN)
Wertung = keras.layers.Dense(64, activation='relu')(Wertung)

Output = keras.layers.Dense((6), activation = 'sigmoid')(Wertung)


model = keras.models.Model(input, Output)

model.compile(loss='binary_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# %% [markdown]
# # Training

# %%
csv_logger = CSVLogger('log.csv', append=True, separator=';')

history = model.fit(x, y, epochs=16, validation_split=0.3, callbacks=[csv_logger])

model.save('model')
# Out:
# Epoch 1/16
# 1/1 [==============================] - 0s 197ms/step - loss: 4.5620 - accuracy: 0.1429 - val_loss: 70.9831 - val_accuracy: 0.8333
# Epoch 2/16
# 1/1 [==============================] - 0s 42ms/step - loss: 106.1294 - accuracy: 0.6429 - val_loss: 27.8189 - val_accuracy: 0.8333
# Epoch 3/16
# 1/1 [==============================] - 0s 44ms/step - loss: 45.2789 - accuracy: 0.6429 - val_loss: 20.2822 - val_accuracy: 0.8333
# Epoch 4/16
# 1/1 [==============================] - 0s 49ms/step - loss: 23.3721 - accuracy: 0.6429 - val_loss: 16.9742 - val_accuracy: 0.8333
# Epoch 5/16
# 1/1 [==============================] - 0s 50ms/step - loss: 18.3817 - accuracy: 0.6429 - val_loss: 9.5702 - val_accuracy: 0.8333
# Epoch 6/16
# 1/1 [==============================] - 0s 44ms/step - loss: 10.0971 - accuracy: 0.6429 - val_loss: 2.9778 - val_accuracy: 0.8333
# Epoch 7/16
# 1/1 [==============================] - 0s 44ms/step - loss: 2.2368 - accuracy: 0.7143 - val_loss: 3.8392 - val_accuracy: 0.0000e+00
# Epoch 8/16
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5956 - accuracy: 0.1429 - val_loss: 0.5269 - val_accuracy: 0.6667
# Epoch 9/16
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7233 - accuracy: 0.2857 - val_loss: 1.7462 - val_accuracy: 0.8333
# Epoch 10/16
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1743 - accuracy: 0.7857 - val_loss: 0.2851 - val_accuracy: 0.8333
# Epoch 11/16
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2070 - accuracy: 0.9286 - val_loss: 0.1544 - val_accuracy: 0.8333
# Epoch 12/16
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1070 - accuracy: 0.7857 - val_loss: 0.2707 - val_accuracy: 0.8333
# Epoch 13/16
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0896 - accuracy: 0.9286 - val_loss: 0.3680 - val_accuracy: 0.8333
# Epoch 14/16
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0957 - accuracy: 0.9286 - val_loss: 0.2707 - val_accuracy: 0.8333
# Epoch 15/16
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0505 - accuracy: 0.9286 - val_loss: 0.2371 - val_accuracy: 0.8333
# Epoch 16/16
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.2351 - val_accuracy: 0.8333

# %% [markdown]
# # Auswertung

# %%
plt.xkcd()

# %%
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.plot(history.history['loss'], label = 'loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 9])
plt.legend(loc='center right')
plt.show()

# %%
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history.history['accuracy'], label = 'accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='center right')
plt.show()

# %% [markdown]
# # Analyse

# %%
fname = 'val.tar.gz'
Download(fname)
# Out:
# Geladen

# %%
# Parse the JSON file and read all the images and labels
with open('publaynet/val.json', 'r') as fp:
    samples = json.load(fp)
# Index images
images = {}
for image in samples['images']:
    images[image['id']] = {'file_name': "publaynet/val/" + image['file_name'], 'annotations': []}
for ann in samples['annotations']:
    images[ann['image_id']]['annotations'].append(ann)

x = []
y = []

# Ausschneiden und ausgeben
for i, (_, image) in enumerate(images.items()):
    with Image.open(image['file_name']) as img:
      TempImage, Kategorie = markup(img, image['annotations'])
      # x.append(TempImage[:, :, 0])
      x.append(TempImage)
      y.append(Kategorie)


x = np.array(x)
y = np.array(y)

print(x.shape)
print(y.shape)
# Out:
# (11245, 120, 120, 3)
# (11245,)

# %%
Ergebnis = []
prediction = model.predict(x)

for i in range(len(prediction)):
  maxWert = 0
  Stelle = 0
  for b in range(len(prediction[0])):
    if(prediction[i][b] > maxWert):
      Stelle = b
      maxWert = prediction[i][b]

  Ergebnis.append(Stelle)

# %%
plt.figure(num=None, figsize=(30, 6), dpi=120, facecolor='w', edgecolor='k')
plt.plot(Ergebnis, label = 'Ergebnis des Models')
plt.plot(y, label ='Eigentliches Ergebnis')

plt.xlabel('Beispiele')
plt.ylabel('Ergebnis')
plt.ylim([0, 10])
plt.xlim([0, len(x)+4])
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(num=None, figsize=(120, 6), dpi=120, facecolor='w', edgecolor='k')

plt.plot(Ergebnis, label = 'Ergebnis des Models')
plt.plot(y, label ='Eigentliches Ergebnis')

plt.xlabel('Beispiele')
plt.ylabel('Ergebnis')
plt.ylim([0, 10])
plt.xlim([0, len(x)+4])
plt.legend(loc='upper right')
plt.show()
